# %% [markdown]
# # **LangChain Document Loaders – Essential Codes Notebook**
# This notebook demonstrates **important LangChain document loaders** used in RAG and GenAI pipelines.
#
# Covered Topics:
# - TextLoader
# - PyPDFLoader
# - CSVLoader
# - JSONLoader
# - DirectoryLoader
# - WebBaseLoader
# - UnstructuredFileLoader
# - Document loading + splitting

# %% [markdown]
# ## **1. Install Required Libraries**

# %%
# !pip install langchain langchain-community unstructured pypdf

# %% [markdown]
# ## **2. Basic TextLoader**

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader('sample.txt')

documents = loader.load()

documents[:1]

# %% [markdown]
# ## **3. PDF Loader (PyPDFLoader)**

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader('sample.pdf')

documents = loader.load()

documents[:2]

# %% [markdown]
# ## **4. CSV Loader**

# %%
from langchain_community.document_loaders import CSVLoader

loader = CSVLoader(file_path='data.csv')

documents = loader.load()

documents[:1]

# %% [markdown]
# ## **5. JSON Loader**

# %%
from langchain_community.document_loaders import JSONLoader

loader = JSONLoader(
    file_path='data.json',
    jq_schema='.',
    text_content=False
)

documents = loader.load()

documents[:1]

# %% [markdown]
# ## **6. Directory Loader (Load Multiple Files)**

# %%
from langchain_community.document_loaders import DirectoryLoader

loader = DirectoryLoader(
    'documents/',
    glob='**/*.txt'
)

docs = loader.load()

len(docs)

# %% [markdown]
# ## **7. WebBaseLoader (Load Website Content)**

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader('https://example.com')

documents = loader.load()

documents[:1]

# %% [markdown]
# ## **8. Unstructured File Loader (Any File Type)**

# %%
from langchain_community.document_loaders import UnstructuredFileLoader

loader = UnstructuredFileLoader('sample.docx')

documents = loader.load()

documents[:1]

# %% [markdown]
# ## **9. Document Loader + Text Splitter (RAG preparation)**

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

chunks = splitter.split_documents(documents)

len(chunks)
